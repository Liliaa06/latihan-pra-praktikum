# %%
print("Amallia Putri Nurul Aziz")#Nama Lengkap
print(2605060058)#NIM
print("Cilacap, 06 Januari 2007")#Tempat Tanggal Lahir
print("Perum BKD Blok 39 No. B389 RT 03 RW 11")#Alamat
print("Perempuan")#Jenis Kelamin
print("Menyanyi")#Hobi
# Out:
# Amallia Putri Nurul Aziz
# 2605060058
# Cilacap, 06 Januari 2007
# Perum BKD Blok 39 No. B389 RT 03 RW 11
# Perempuan
# Menyanyi
